# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
output1 = pd.read_csv('output1.csv')
output1
# Out:
#            datetime          location_x  temperature  humidity    co2  light  \
# 0      3/25/17 9:05  Georgetown-default         22.6      36.9  781.0  430.0
# 1      3/25/17 9:06  Georgetown-default         23.8      39.0  767.0  448.0
# 2      3/25/17 9:06  Georgetown-default         23.8      39.0  754.0  423.0
# 3      3/25/17 9:06  Georgetown-default         23.8      39.0  768.0  412.0
# 4      3/25/17 9:06  Georgetown-default         23.8      39.0  758.0  428.0
# 5      3/25/17 9:06  Georgetown-default         23.8      38.9  776.0  419.0
# 6      3/25/17 9:06  Georgetown-default         23.8      38.9  755.0  423.0
# 7      3/25/17 9:06  Georgetown-default         23.8      38.9  755.0  409.0
# 8      3/25/17 9:06  Georgetown-default         23.8      38.9  766.0  447.0
# 9      3/25/17 9:06  Georgetown-default         23.8      39.0  771.0  423.0
# 10     3/25/17 9:06  Georgetown-default         23.8      38.9  789.0  437.0
# ...

# %%
output1['bluetooth_devices'].describe()
# Out:
# count    2628.000000
# mean      197.413242
# std       104.561879
# min        21.000000
# 25%       136.000000
# 50%       182.000000
# 75%       289.000000
# max       424.000000
# Name: bluetooth_devices, dtype: float64

# %%
output1 = output1[['datetime','temperature','humidity','co2','light','noise','bluetooth_devices','count_total']]
output1
# Out:
#            datetime  temperature  humidity     co2  light  noise  \
# 10538   4/8/17 9:15         21.4      24.5   975.0  170.0  515.0
# 10539   4/8/17 9:15         21.4      24.5   975.0  170.0  515.0
# 10540   4/8/17 9:15         21.4      24.5   975.0  170.0  515.0
# 10541   4/8/17 9:15         21.4      24.5   975.0  170.0  515.0
# 10542   4/8/17 9:15         21.4      24.5   975.0  170.0  515.0
# 10543   4/8/17 9:15         21.4      24.5   975.0  170.0  515.0
# 10544   4/8/17 9:15         21.4      24.5   975.0  170.0  515.0
# 10545   4/8/17 9:15         21.4      24.5   975.0  170.0  515.0
# 10546   4/8/17 9:15         21.4      24.5   975.0  170.0  515.0
# 10547   4/8/17 9:15         21.4      24.5   975.0  170.0  515.0
# 10548   4/8/17 9:15         21.4      24.5   975.0  170.0  515.0
# 10549   4/8/17 9:15         21.4      24.5   975.0  170.0  515.0
# 10550   4/8/17 9:15         21.4      24.5   975.0  170.0  515.0
# ...

# %%
#correlation on output1 data
corrmat1 = output1.corr()
corrmat1
# Out:
#                    temperature  humidity       co2     light     noise  \
# temperature           1.000000 -0.633707  0.480579  0.003419  0.023794
# humidity             -0.633707  1.000000 -0.282544 -0.025295 -0.061413
# co2                   0.480579 -0.282544  1.000000  0.010105  0.052222
# light                 0.003419 -0.025295  0.010105  1.000000 -0.002611
# noise                 0.023794 -0.061413  0.052222 -0.002611  1.000000
# bluetooth_devices     0.756414 -0.651096  0.443814 -0.000110  0.038289
# count_total           0.134884 -0.160474  0.132761 -0.030154  0.034503
#
#                    bluetooth_devices  count_total
# temperature                 0.756414     0.134884
# humidity                   -0.651096    -0.160474
# co2                         0.443814     0.132761
# light                      -0.000110    -0.030154
# noise                       0.038289     0.034503
# bluetooth_devices           1.000000     0.167562
# ...

# %%
#a graph to entertain the author
sns.heatmap(corrmat1, vmax=.8, square=True)
plt.show()

# %%
#correlation on output2 data
output2 = pd.read_csv('output1.csv')
output2 = output2[['datetime','temperature','humidity','co2','light','noise','bluetooth_devices','count_total']]
corrmat2 = output2.corr()
corrmat2
# Out:
#                    temperature  humidity       co2     light     noise  \
# temperature           1.000000  0.777036  0.247643 -0.001541 -0.029297
# humidity              0.777036  1.000000  0.121430 -0.009522 -0.154507
# co2                   0.247643  0.121430  1.000000 -0.000139 -0.024570
# light                -0.001541 -0.009522 -0.000139  1.000000  0.001032
# noise                -0.029297 -0.154507 -0.024570  0.001032  1.000000
# bluetooth_devices     0.157448  0.125888  0.504044 -0.003630 -0.016204
# count_total           0.046840  0.052296  0.157657 -0.020356  0.016045
#
#                    bluetooth_devices  count_total
# temperature                 0.157448     0.046840
# humidity                    0.125888     0.052296
# co2                         0.504044     0.157657
# light                      -0.003630    -0.020356
# noise                      -0.016204     0.016045
# bluetooth_devices           1.000000     0.085552
# ...

# %%
#a graph to entertain the author
sns.heatmap(corrmat2, vmax=.8, square=True)
plt.show()
