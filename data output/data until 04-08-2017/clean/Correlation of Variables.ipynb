# %%
import pandas as pd 
import numpy as np
import matplotlib.pylab as plt

# %%
# Read Data
data = pd.read_csv('full_sensor_data--only_04-08-17.csv', usecols=['datetime','temperature', 'humidity', 'co2'])
data.describe()
# Out:
#        temperature     humidity          co2
# count  4575.000000  4575.000000  4575.000000
# mean     21.619060    22.744372  1059.723497
# std      15.095144    15.136429    88.144019
# min    -999.000000  -999.000000     2.000000
# 25%      21.700000    22.300000  1030.000000
# 50%      21.800000    22.800000  1082.000000
# 75%      22.100000    23.600000  1110.000000
# max      22.700000    25.800000  1214.000000

# %%
# Eliminating outliers

data = data [data.temperature > 0]
data = data [data.co2 != 2]
data.describe()
# Out:
#        temperature     humidity          co2
# count  4566.000000  4566.000000  4566.000000
# mean     21.842291    22.965922  1061.808366
# std       0.278913     0.905860    74.663511
# min      21.200000    20.800000   763.000000
# 25%      21.700000    22.300000  1031.000000
# 50%      21.800000    22.800000  1082.000000
# 75%      22.100000    23.600000  1110.000000
# max      22.700000    25.800000  1214.000000

# %%
# Identifying correlation between variables 

import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['font.size']=11
plt.rcParams['figure.figsize']=[15.0, 5.5]
fig, axes=plt.subplots(nrows=1, ncols=2)
data.plot(kind='scatter', x='humidity', y='co2', ax=axes[0], color='Blue');
data.plot(kind='scatter', x='humidity', y='temperature', ax=axes[1], color='Red');
plt.tight_layout()

# %%
 # Scatter Matrix of the Variables
from pandas.tools.plotting import scatter_matrix

grouped = data.groupby(level=0)
dfgroup = grouped.mean()

scatter_matrix(dfgroup,figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10d0d7ac8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11124ce10>]], dtype=object)
